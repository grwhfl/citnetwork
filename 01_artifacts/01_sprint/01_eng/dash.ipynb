# %%
import sqlalchemy
import pandas as pd

# %%
engine = sqlalchemy.create_engine(url="postgresql://mdb:Gsdbe4k754ghmf@185.87.50.149:6432/dblp")
con = engine.connect()
pd.read_sql("select * from information_schema.tables", con=con)
# Out:
#     table_catalog        table_schema                    table_name  \
# 0            dblp               dblps                        traw13
# 1            dblp               dblps              tarticle_keyword
# 2            dblp               dblps                       tauthor
# 3            dblp               dblps                      tsmall13
# 4            dblp               dblps                      tarticle
# ..            ...                 ...                           ...
# 189          dblp  information_schema  foreign_data_wrapper_options
# 190          dblp  information_schema        foreign_server_options
# 191          dblp  information_schema               foreign_servers
# 192          dblp  information_schema          user_mapping_options
# 193          dblp  information_schema                foreign_tables
#
#      table_type self_referencing_column_name reference_generation  \
# 0    BASE TABLE                         None                 None
# ...

# %%
articles = pd.read_sql("select * from dblps.tarticle limit 100", con=con)
articles.head()
# Out:
#       idx  batch                        id  \
# 0  401557      1  53e99d65b7602d970261f607
# 1  401558      1  53e99d65b7602d970261f610
# 2  401780      1  53e99d65b7602d970262055c
# 3  401559      1  53e99d65b7602d970261f649
# 4  401560      1  53e99d65b7602d970261f662
#
#                                                title  year n_citation  \
# 0  Performance study of bandwidth reallocation al...  2001          4
# 1  Source level debugging of automatically parall...  1991          7
# 2  A New Approach to Provide Real-Time Services o...  2001          7
# 3  Towards Understanding Deterrence: Information ...  2011         11
# 4  Accentual Transfer from Swiss-German to French...  2012          5
#
#   page_start page_end doc_type lang publisher volume issue  \
# 0        700      706     None   en      None     24    14
# 1        132      143     None   en      None     26    12
# 2        124      124     None   en      None
# 3         21       37     None   en      None
# ...

# %%
import psycopg2

# Connect to your postgres DB
conn = psycopg2.connect("dbname=test user=postgres")

# Open a cursor to perform database operations
cur = conn.cursor()

# Execute a query
cur.execute("SELECT * FROM my_data")

# Retrieve query results
records = cur.fetchall()
